# %%
# !python word_embedding.py -emb_name glove -sf ../preprocessed_data/whole_comments_filtered.txt -gv_vocab ../preprocessed_data/glove/vocab.pkl -gv_cooccur ../preprocessed_data/glove/cooccurrence.pkl
# Out:
# Using TensorFlow backend.
# 2019-07-28 22:12:43,228 INFO Generate glove embedding...
# 2019-07-28 22:12:43,234 INFO Vocab file loaded
# 2019-07-28 22:12:43,245 INFO Check vocab order: food, organic
# 2019-07-28 22:12:45,074 INFO Cooccurence to matrix of shape: (18000, 18000)
# 2019-07-28 22:12:45,074 INFO get pre-trained glove embedding
# 2019-07-28 22:13:17,599 INFO Start fine tuning...
# 2019-07-28 22:13:30.077028: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-07-28 22:13:30.077686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: GeForce GTX TITAN X major: 5 minor: 2 memoryClockRate(GHz): 1.076
# pciBusID: 0000:01:00.0
# totalMemory: 11.92GiB freeMemory: 11.81GiB
# 2019-07-28 22:13:30.077713: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# ...

# %%
from word_embedding import Glove
gv = Glove()
gv.convert_glove_2_w2v('../preprocessed_data/glove/vocab.pkl', '../preprocessed_data/glove/fine_tuned_glove_300','../preprocessed_data/glove/glove_w2v_300_filtered.txt')
# Out:
# Using TensorFlow backend.
# 2019-07-28 23:06:30,608 INFO glove embedding loaded
# 2019-07-28 23:06:30,617 INFO Vocab file loaded
# 2019-07-28 23:06:30,628 INFO Check vocab order: food, organic

# %%
from word_embed_reader import GloveEmbedding
gv_reader = GloveEmbedding('../preprocessed_data/glove/','glove_w2v_300.txt')
# Out:
# 2019-07-19 01:03:02,136	Loading embeddings from: ../preprocessed_data/glove/glove_w2v_300.txt
# 2019-07-19 01:03:02,138	loading projection weights from ../preprocessed_data/glove/glove_w2v_300.txt
# 2019-07-19 01:03:02,140	{'uri': '../preprocessed_data/glove/glove_w2v_300.txt', 'mode': 'rb', 'encoding': None, 'ignore_ext': False, 'buffering': -1, 'transport_params': None, 'errors': None, 'newline': None, 'opener': None, 'closefd': True}
# 2019-07-19 01:03:07,729	loaded (15000, 300) matrix from ../preprocessed_data/glove/glove_w2v_300.txt
# 2019-07-19 01:03:08,695	#vectors: 15000, #dimensions: 300

# %%
gv_reader.get_emb_given_word('food')
# Out:
# [0.049474858,
#  0.48517805,
#  0.23767084,
#  -0.14581981,
#  -0.109061465,
#  0.38969976,
#  0.35048884,
#  0.50957555,
#  0.116252795,
#  -2.2164803,
#  0.17640635,
#  -1.2593341,
#  -0.22547498,
#  0.66239023,
#  0.34893072,
#  -0.24227284,
#  -0.33844092,
#  -0.011624739,
#  0.044034675,
#  0.25400507,
#  -0.16764994,
#  0.31661874,
#  0.7881865,
#  0.23527506,
#  0.10151268,
#  0.80145323,
#  -0.67286307,
#  0.26220474,
#  0.19148603,
#  -0.101668686,
#  -0.8392558,
#  0.57451135,
#  -0.6138978,
#  0.16369607,
#  -1.030808,
#  0.11735541,
#  -0.13608332,
#  -0.55587316,
#  -0.39364988,
#  -0.17232311,
#  -0.64966065,
#  -0.6326507,
#  0.6512089,
#  0.7067038,
#  -0.7384645,
#  -0.6120673,
#  -0.23735583,
#  -0.49620974,
#  -0.38945463,
#  0.37949246,
#  -0.060676195,
#  0.038708642,
#  0.49551702,
#  0.15730074,
#  0.11020246,
#  0.37302205,
#  0.7611477,
#  -0.15517145,
#  0.20476083,
#  -0.36180753,
#  -0.18647924,
#  -0.0036708117,
#  0.7506269,
#  0.12653938,
# ...

# %%
-gv_vocab ../preprocessed_data/glove/vocab.pkl -gv_cooccur ../preprocessed_data/glove/cooccurrence.pkl

# %% [markdown]
# ## German Data

# %% [markdown]
# Check dimension of pretrained glove trained on german wikipedia

# %%
import check

# %%
check.check_dim('../preprocessed_data/german/glove/vectors.txt')
# Out:
# 300

# %%
# !python word_embedding.py -emb_name glove -sf ../preprocessed_data/german/whole_comments.txt -lang de -gv_vocab ../preprocessed_data/german/glove/fine_tune/vocab.pkl -gv_cooccur ../preprocessed_data/german/glove/fine_tune/cooccurrence.pkl
# Out:
# Using TensorFlow backend.
# 2019-07-24 09:33:08,626	Generate glove embedding...
# 2019-07-24 09:33:08,635	Vocab file loaded
# 2019-07-24 09:33:08,648	Check vocab order: mehr, gut
# 2019-07-24 09:33:10,732	Cooccurence to matrix of shape: (18000, 18000)
# 2019-07-24 09:33:10,732	get pre-trained glove embedding
# 2019-07-24 09:34:23,126	Start fine tuning...
# 2019-07-24 09:34:35.727019: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-07-24 09:34:35.727656: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: GeForce GTX TITAN X major: 5 minor: 2 memoryClockRate(GHz): 1.076
# pciBusID: 0000:01:00.0
# totalMemory: 11.92GiB freeMemory: 11.64GiB
# 2019-07-24 09:34:35.727684: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# ...

# %%
from word_embedding import Glove
gv = Glove()
gv.convert_glove_2_w2v('../preprocessed_data/german/glove/fine_tune/vocab.pkl', '../preprocessed_data/german/glove/fine_tune/fine_tuned_glove_300','../preprocessed_data/german/glove/fine_tune/glove_w2v_300.txt')
# Out:
# Using TensorFlow backend.
# 2019-07-24 10:40:43,812	glove embedding loaded
# 2019-07-24 10:40:43,821	Vocab file loaded
# 2019-07-24 10:40:43,832	Check vocab order: mehr, gut
